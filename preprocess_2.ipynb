# %%
import pandas as pd
import collections
import json
import numpy as np

# %%
df = pd.read_excel("raw_data//daily_price_all.xlsx")

# %%
df.head(15)
# Out:
#              Unnamed: 0 Last Refresh: 2019-11-27 22:36:55         Unnamed: 2  \
# 0        Calendar Basis                               NaN                NaN
# 1             Portfolio                                              Default
# 2                  Item
# 3             Frequency                                일간                KRW
# 4       Non-Trading Day                          Previous                Asc
# 5       Include Weekend                              NONE
# 6                  Term                          20090101  Current(20191127)
# 7                Symbol                           A005930            A000660
# 8           Symbol Name                              삼성전자             SK하이닉스
# 9                  Kind                               SSC                SSC
# 10                 Item                        S41000170F         S41000170F
# 11            Item Name                            수익률(%)             수익률(%)
# ...

# %%
df.columns = df.iloc[7]
df = df[13:]
df = df.set_index('Symbol')

# %%
hey = df.values[1]

# %%
np.isnan(np.array(hey))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-60ebfc42d98b> in <module>
# ----> 1 np.isnan(np.array(hey))
#
# TypeError: ufunc 'isnan' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''

# %%
#idx of double 
double_idx = np.full(len(df.index), False, dtype = bool)

for i in range(len(df.index)) :
    oneday_arr = df.values[i]
  
    if i ==0 :
        pre_arr = oneday_arr
        continue ;
    #get non np array for calc norm distance btw pre & curr day return 
    nz_idx = np.isnan(oneday_arr)

    if np.linalg.norm(oneday_arr[~nz_idx]  - pre_arr[~nz_idx]) < 0.001 :
        double_idx[i] = True
        

    pre_arr = oneday_arr
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-e3dc87289959> in <module>
#       9         continue ;
#      10     #get non np array for calc norm distance btw pre & curr day return
# ---> 11     nz_idx = np.isnan(oneday_arr)
#      12
#      13     if np.linalg.norm(oneday_arr[~nz_idx]  - pre_arr[~nz_idx]) < 0.001 :
#
# TypeError: ufunc 'isnan' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''

# %%
price_js = price.to_json(orient='columns')
with open('data//daily_price.json', 'w') as outfile:
    json.dump(price_js, outfile)
